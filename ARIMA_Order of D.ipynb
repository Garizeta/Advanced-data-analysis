# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.core import datetools
from pandas import Series, DataFrame
import pandas as pd

series = read_csv('winnebago.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)
print(series.head())
# Out:
# Month
# 1966-11-01    61.0
# 1966-12-01    48.0
# 1967-01-01    53.0
# 1967-02-01    78.0
# 1967-03-01    75.0
# Name: Monthly unit sales, Winnebago Industries, Nov. 1966 ? Feb. 1972, dtype: float64

# %%
from pandas.tools.plotting import autocorrelation_plot
from statsmodels.graphics.tsaplots import plot_acf
plot_acf(series)

# %%
#Start Arima 
from statsmodels.tsa.arima_model import ARIMA

# %%
series.plot()
pyplot.show()

# %%
plot_acf(series,lags=12)

# %%
diff = series.diff(periods=1)
diff.dropna(inplace=True)
plot_acf(diff,lags=12)

# %%
print (series.std())
# Out:
# 374.5662981454007

# %%
print (diff.std())
# Out:
# 223.25400383960587

# %%
diff2 = series.diff(periods=2)
diff2.dropna(inplace=True)
print (diff2.std())
# Out:
# 224.94561067753312

# %%
diff.plot()
pyplot.show()
